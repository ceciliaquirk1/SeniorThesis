# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import statistics
from collections import Counter
import networkx as nx

# %%
hurricane_harvey_df = pd.read_csv('/home/cquirk/EventCSVs/hurricane_harvey_df.csv')
hurricane_irma_df = pd.read_csv('/home/cquirk/EventCSVs/hurricane_irma_df.csv')
earthquake_mexico_df = pd.read_csv('/home/cquirk/EventCSVs/earthquake_mexico_df.csv')
hurricane_maria_df = pd.read_csv('/home/cquirk/EventCSVs/hurricane_maria_df.csv')
earthquake_costarica_df = pd.read_csv('/home/cquirk/EventCSVs/earthquake_costarica_df.csv')
earthquake_iran_iraq_df = pd.read_csv('/home/cquirk/EventCSVs/earthquake_iran_iraq_df.csv')
mudslide_california_df = pd.read_csv('/home/cquirk/EventCSVs/mudslide_california_df.csv')
windstorm_friederike_df = pd.read_csv('/home/cquirk/EventCSVs/windstorm_friederike_df.csv')
wildfire_nairobi_df = pd.read_csv('/home/cquirk/EventCSVs/wildfire_nairobi_df.csv')

riot_hamburg_G20_df = pd.read_csv('/home/cquirk/EventCSVs/riot_hamburg_G20_df.csv')
riot_charlottesville_df = pd.read_csv('/home/cquirk/EventCSVs/riot_charlottesville_df.csv')
riot_catalonia_df = pd.read_csv('/home/cquirk/EventCSVs/riot_catalonia_df.csv')
riot_philadelphia_superbowl_df = pd.read_csv('/home/cquirk/EventCSVs/riot_philadelphia_superbowl.csv')

school_shooting_tehama_county_df = pd.read_csv('/home/cquirk/EventCSVs/school_shooting_tehama_county_df.csv')
shooting_trebes_france_df = pd.read_csv('/home/cquirk/EventCSVs/shooting_trebes_france_df.csv')
shooting_youtube_HQ_df = pd.read_csv('/home/cquirk/EventCSVs/shooting_youtube_HQ_df.csv')
van_attack_muenster_df = pd.read_csv('/home/cquirk/EventCSVs/van_attack_muenster_df.csv')
school_shooting_santa_fe_df = pd.read_csv('/home/cquirk/EventCSVs/school_shooting_santa_fe_df.csv')

# %%
events = [hurricane_harvey_df, hurricane_irma_df, earthquake_mexico_df, hurricane_maria_df, 
          earthquake_costarica_df, earthquake_iran_iraq_df, mudslide_california_df, windstorm_friederike_df,
          wildfire_nairobi_df, riot_hamburg_G20_df, riot_charlottesville_df, riot_catalonia_df, riot_philadelphia_superbowl_df,
          school_shooting_tehama_county_df, shooting_trebes_france_df, shooting_youtube_HQ_df, van_attack_muenster_df, 
          school_shooting_santa_fe_df]
event_names = ['Hurricane Harvey', 'Hurricane Irma', 'Mexico Earthquake', 'Hurricane Maria', 
          'Costa Rica Earthquake', 'Iran/Iraq Earthquake', 'California Mudslide', 'Friederike Windstorm',
          'Nairobi Wildfire', 'Hamburg G20 Riot', 'Charlottesville Riot', 'Catalonia Riot', 'Philadelphia Superbowl Riot',
          'Tehama County Shooting', 'Trebes, France Shooting', 'YouTube HQ Shooting', 'Muenster Van Attack', 
          'Santa Fe School Shooting']
event_types = ['Natural Disaster','Natural Disaster','Natural Disaster','Natural Disaster','Natural Disaster','Natural Disaster',
               'Natural Disaster','Natural Disaster','Natural Disaster', 'Riot', 'Riot', 'Riot', 'Riot', 'Shooting/Terror',
              'Shooting/Terror', 'Shooting/Terror', 'Shooting/Terror', 'Shooting/Terror']

# %%
event_summary = pd.DataFrame()

n = len(events)

event_summary['Name'] = [0]*n
event_summary['Category'] = [0]*n
event_summary['Start Date'] = [0]*n
event_summary['End Date'] = [0]*n
event_summary['Number of Days'] = [0]*n
event_summary['Number of Users'] = [0]*n
event_summary['Number of Messages'] = [0]*n

# %%
for i in range(len(events)):
    event_summary['Name'][i] = event_names[i]
    event_summary['Category'][i] = event_types[i]
# Out:
# /tmp/ipykernel_1074055/1032697057.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_summary['Category'][i] = event_types[i]
# /usr/licensed/anaconda3/2021.11/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#get dates
for i in range(len(events)):
    #get dates as list
    input_df = events[i]
    dates = Counter(input_df['Timestamp'])
    dates = list(dates.keys())
    dates = sorted(dates)
    num_days = len(dates)
    first_day = dates[0]
    last_day = dates[-1]
    event_summary['Start Date'][i] = first_day
    event_summary['End Date'][i] = last_day
    event_summary['Number of Days'][i] = num_days
# Out:
# /tmp/ipykernel_1074055/3062843863.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_summary['Number of Days'][i] = num_days

# %%
#get nodes and edges count
for i in range(len(events)):
    input_df = events[i]
    G = nx.from_pandas_edgelist(input_df, source = 'Source', target = 'Target', create_using=nx.MultiDiGraph())
    event_summary['Number of Users'][i] = G.number_of_nodes()
    event_summary['Number of Messages'][i] = G.number_of_edges()
    event_summary['Density'][i] = nx.density(G)
    event_summary['Centrality Measure'][i] = nx.node_connectivity(G)
# Out:
# /tmp/ipykernel_1074055/1244780410.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_summary['Number of Users'][i] = G.number_of_nodes()
# /tmp/ipykernel_1074055/1244780410.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_summary['Number of Messages'][i] = G.number_of_edges()
# /tmp/ipykernel_1074055/1244780410.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_summary['Density'][i] = nx.density(G)
# /tmp/ipykernel_1074055/1244780410.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_summary['Centrality Measure'][i] = nx.node_connectivity(G)

# %%
event_summary
# Out:
#                            Name          Category  Start Date    End Date  \
# 0              Hurricane Harvey  Natural Disaster  2017-08-23  2017-09-11
# 1                Hurricane Irma  Natural Disaster  2017-09-04  2017-09-18
# 2             Mexico Earthquake  Natural Disaster  2017-09-07  2017-09-28
# 3               Hurricane Maria  Natural Disaster  2017-09-21  2017-10-04
# 4         Costa Rica Earthquake  Natural Disaster  2017-11-13  2017-12-01
# 5          Iran/Iraq Earthquake  Natural Disaster  2017-11-12  2017-12-02
# 6           California Mudslide  Natural Disaster  2018-01-07  2018-01-27
# 7          Friederike Windstorm  Natural Disaster  2018-01-17  2018-01-28
# 8              Nairobi Wildfire  Natural Disaster  2018-01-28  2018-02-01
# 9              Hamburg G20 Riot              Riot  2017-07-06  2017-07-17
# 10         Charlottesville Riot              Riot  2017-08-10  2017-08-16
# 11               Catalonia Riot              Riot  2017-09-28  2017-10-16
# 12  Philadelphia Superbowl Riot              Riot  2018-02-04  2018-02-10
# 13       Tehama County Shooting   Shooting/Terror  2017-11-14  2017-12-02
# 14      Trebes, France Shooting   Shooting/Terror  2018-03-23  2018-04-08
# 15          YouTube HQ Shooting   Shooting/Terror  2018-04-03  2018-04-10
# 16          Muenster Van Attack   Shooting/Terror  2018-04-07  2018-04-14
# 17     Santa Fe School Shooting   Shooting/Terror  2018-05-18  2018-05-25
#
#     Number of Days  Number of Users  Number of Messages  Density  \
# 0               20           281724              494046        0
# 1               15           189969              348089        0
# 2               22            45882               54796        0
# 3               13            60353               97916        0
# 4               11              601                 512        0
# 5               21             7639                9451        0
# 6               18             8609               12719        0
# 7                9             3486                3239        0
# 8                5              695                 915        0
# 9               12            25429               58768        0
# 10               7            84638              152209        0
# 11              19            27432               54266        0
# 12               7             1164                1022        0
# 13              19             3884                4140        0
# 14              17             4199                4414        0
# 15               8            34611               47262        0
# 16               8             1824                2737        0
# 17               8            30093               50208        0
#
#     Input Degree  Output Degree  Centrality Measure
# 0              0              0                   0
# 1              0              0                   0
# 2              0              0                   0
# 3              0              0                   0
# 4              0              0                   0
# 5              0              0                   0
# 6              0              0                   0
# 7              0              0                   0
# 8              0              0                   0
# 9              0              0                   0
# 10             0              0                   0
# 11             0              0                   0
# 12             0              0                   0
# 13             0              0                   0
# 14             0              0                   0
# 15             0              0                   0
# 16             0              0                   0
# 17             0              0                   0
